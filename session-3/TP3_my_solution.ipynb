# %%
# MNIST with an MLP, from scratch

# - Step 1: build an MLP from scratch to solve MNIST. Question set: https://fleuret.org/dlc/materials/dlc-practical-3.pdf
# - Step 2: debug your network with backprop ninja and a reference implementation using torch's .backward()
# - Step 3: build the same MLP but will full pytorch code (nn.Linear, etc.)

# %%
pip install torchviz

# %%
pip install --upgrade pip

# %%
pip install matplotlib

# %%
import math
import torch
from torch import nn
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
pip install torchvision
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting torchvision
#   Downloading torchvision-0.21.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (6.1 kB)
# Requirement already satisfied: numpy in /Users/come/Library/Python/3.9/lib/python/site-packages (from torchvision) (2.0.2)
# Requirement already satisfied: torch==2.6.0 in /Users/come/Library/Python/3.9/lib/python/site-packages (from torchvision) (2.6.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/come/Library/Python/3.9/lib/python/site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: filelock in /Users/come/Library/Python/3.9/lib/python/site-packages (from torch==2.6.0->torchvision) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/come/Library/Python/3.9/lib/python/site-packages (from torch==2.6.0->torchvision) (4.12.2)
# Requirement already satisfied: networkx in /Users/come/Library/Python/3.9/lib/python/site-packages (from torch==2.6.0->torchvision) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/come/Library/Python/3.9/lib/python/site-packages (from torch==2.6.0->torchvision) (3.1.5)
# Requirement already satisfied: fsspec in /Users/come/Library/Python/3.9/lib/python/site-packages (from torch==2.6.0->torchvision) (2025.2.0)
# Requirement already satisfied: sympy==1.13.1 in /Users/come/Library/Python/3.9/lib/python/site-packages (from torch==2.6.0->torchvision) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/come/Library/Python/3.9/lib/python/site-packages (from sympy==1.13.1->torch==2.6.0->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/come/Library/Python/3.9/lib/python/site-packages (from jinja2->torch==2.6.0->torchvision) (3.0.2)
# Downloading torchvision-0.21.0-cp39-cp39-macosx_11_0_arm64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 15.0 MB/s eta 0:00:00
# Installing collected packages: torchvision
# Successfully installed torchvision-0.21.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from utils import load_data

# %%
train_input, train_target, test_input, test_target = load_data(one_hot_labels = True, normalize = True)
# Out:
# * Using MNIST
# 100.0%
# 100.0%
# 100.0%
# 100.0%
# ** Reduce the data-set (use --full for the full thing)
# ** Use 1000 train and 1000 test samples

# %%
plt.imshow(train_input[4].view((28,28)))

# %%
def compute_accuracy (preds, targets):
    """ Computes the accuracy between predictions and targets. Data is expected to be one-hot encoded. """
    _, idx1 = torch.max(preds, dim=1)
    _, idx2 = torch.max(targets, dim=1)
    d = idx1 == idx2
    return d.int().float().mean().item()

# %%
# unit test
# this cell should return 0.75
preds = torch.zeros((4,7))
preds[0,1] = 1
preds[1,4] = 1
preds[2,2] = 1
preds[3,6] = 1
targets = torch.zeros((4,7))
targets[0,1] = 1
targets[1,4] = 1
targets[2,2] = 1
targets[3,2] = 1
compute_accuracy(preds, targets)
# Out:
# 0.75

# %%
def sigma(x):
    return torch.tanh(x)

def dsigma(x):
    return 1 - torch.pow(sigma(x), 2)

# %%
def loss (v,t):
    return(torch.sum (torch.pow(v-t,2)))

def dloss(v,t):
    return torch.mul(2, (v-t))

# %%
# sanity check
v = torch.randn((3, 6), dtype=torch.float32)
t = torch.randn((3, 6), dtype=torch.float32)
l=loss(v,t)
dloss(v,t)
# Out:
# tensor([[ 2.5200,  0.5142, -5.1918,  6.6978,  4.5144,  0.7991],
#         [-1.4717, -2.3068,  2.6923, -2.8075,  2.1203,  2.7675],
#         [-1.0418,  2.7750, -2.5335, -5.4650, -0.4003,  1.7546]])

# %%
# multiply targets by 0.9 to be in the range of tanh
train_target *= 0.9
test_target *= 0.9

# %% [markdown]
# ### Step 1: Backprop ninja

# %%
# utility function we will use later when comparing manual gradients to PyTorch gradients
# DO NOT MODIFY IT
#
def cmp(s, dt, t):
  ex = torch.all(dt == t.grad).item()
  app = torch.allclose(dt, t.grad)
  maxdiff = (dt - t.grad).abs().max().item()
  print(f'{s:15s} | exact: {str(ex):5s} | approximate: {str(app):5s} | maxdiff: {maxdiff}')

# %%
torch.manual_seed(1337)
w1 = torch.ones((784, 50), requires_grad=True)
b1 = torch.ones((50), requires_grad=True)
w2 = torch.ones((50, 10), requires_grad=True)
b2 = torch.ones((10), requires_grad=True)
parameters = [w1, b1, w2, b2]
for p in parameters:
    p.requires_grad = True

# %%
x1 = train_input[:5]
y1 = train_target[:5]
z1 = x1 @ w1 + b1.t()
h1 = sigma(z1)
z2 = h1 @ w2 + b2.t()
h2 = sigma(z2)
l = loss(h2, y1)
h2.shape, l
# Out:
# (torch.Size([5, 10]), tensor(55.8500, grad_fn=<SumBackward0>))

# %%
# Force pytorch to retain grade for intermediate nodes and reset grad for parameters
# DO NOT MODIFY THIS CODE
#
others = [h2,z2,h1,z1]
for p in parameters:
    p.grad = None
for t in others:
    t.retain_grad()
l.backward()
print(f'loss={l}')
# Out:
# loss=55.849998474121094

# %%
b2.grad.shape
# Out:
# torch.Size([10])

# %%
# here we compare our gradient to the reference gradient computed by pytorch
dl = 1.0
dh2 = dloss(h2, y1)
cmp('h2',dh2,h2)
dz2 = torch.mul(dh2, dsigma(z2))
cmp('z2',dz2, z2)
dw2 = h1.t() @ dz2
cmp('w2',dw2, w2)
db2 = dz2.sum(0).reshape(b2.shape)
cmp('b2',db2, b2)
dh1 = dz2 @ w2.t()
cmp('h1',dh1, h1)
dz1 = torch.mul(dh1, dsigma(z1))
cmp('z1', dz1, z1)
dw1 = x1.t() @ dz1
cmp('w1', dw1, w1)
db1 = dz1.sum(0).reshape(b1.shape)
cmp('b1', db1, b1)
# Out:
# h2              | exact: True  | approximate: True  | maxdiff: 0.0
# z2              | exact: True  | approximate: True  | maxdiff: 0.0
# w2              | exact: True  | approximate: True  | maxdiff: 0.0
# b2              | exact: True  | approximate: True  | maxdiff: 0.0
# h1              | exact: True  | approximate: True  | maxdiff: 0.0
# z1              | exact: True  | approximate: True  | maxdiff: 0.0
# w1              | exact: True  | approximate: True  | maxdiff: 0.0
# b1              | exact: True  | approximate: True  | maxdiff: 0.0

# %%
lr = 0.1
with torch.no_grad():
    w1 += -lr * dw1
    b1 += -lr * db1.squeeze()
    w2 += -lr * dw2
    b2 += -lr * db2.squeeze()

# %%
l = loss(h2, y1)
l.item()
# Out:
# 55.849998474121094

# %% [markdown]
# ##### Now that we've checked our gradients are correct, we can implement the network

# %%
def forward(w1, b1, w2, b2, x):
    z1 = x @ w1 + b1.t()
    h1 = sigma(z1)
    z2 = h1 @ w2 + b2.t()
    h2 = sigma(z2)
    return z1, h1, z2, h2

# %%
def backward(w1, b1, w2, b2, x1, y1, h2, z2, h1, z1):
    dl = 1.0
    dh2 = dloss(h2, y1)
    dz2 = torch.mul(dh2, dsigma(z2))
    dw2 = h1.t() @ dz2
    db2 = dz2.sum(0).reshape(b2.shape)
    dh1 = dz2 @ w2.t()
    dz1 = torch.mul(dh1, dsigma(z1))
    dw1 = x1.t() @ dz1
    db1 = dz1.sum(0).reshape(b1.shape)
        
    return dw1, db1, dw2, db2

# %%
def update(w1, b1, w2, b2, dw1, db1, dw2, db2, lr):
    with torch.no_grad():
        w1 += -lr * dw1
        b1 += -lr * db1.squeeze()
        w2 += -lr * dw2
        b2 += -lr * db2.squeeze()
    return w1, b1, w2, b2

# %%
def init():
    """ init a network """
    torch.manual_seed(1337)
    w1 = torch.randn((784, 50), requires_grad=True)
    b1 = torch.randn((50), requires_grad=True)
    w2 = torch.randn((50, 10), requires_grad=True)
    b2 = torch.randn((10), requires_grad=True)
    return w1, b1, w2, b2

# %%
w1, b1, w2, b2 = init()
parameters = [w1, b1, w2, b2]
for p in parameters:
    p.requires_grad_(True)

# %%
# main training loop
torch.set_printoptions(linewidth=200)
def train(w1, b1, w2, b2):
    lossi = []
    for step in range(10000):
        xb = train_input
        yb = train_target
        num_samples = xb.shape[0]
        # forward
        z1, h1, z2, h2 = forward(w1, b1, w2, b2, xb)
        lsi = loss(h2, yb)
        # backward
        dw1, db1, dw2, db2 = backward(w1, b1, w2, b2, xb, yb, h2, z2, h1, z1)
        # update
        lr = 0.1 / num_samples if step < 5000 else 0.01 / num_samples
        w1, b1, w2, b2 = update(w1, b1, w2, b2, dw1, db1, dw2, db2, lr)
        if step % 100 == 0: print(f'step = {step}, loss = {lsi}')
        lossi.append(lsi.item())
    # compute accuracy
    _, _, _, preds = forward(w1, b1, w2, b2, train_input)
    train_accuracy = compute_accuracy(preds, train_target)
    _, _, _, preds = forward(w1, b1, w2, b2, test_input)
    test_accuracy = compute_accuracy(preds, test_target)
    print(f'{train_accuracy=}')
    print(f'{test_accuracy=}')
    return lossi

# %%
lossi = train(w1, b1, w2, b2)
# Out:
# step = 0, loss = 9739.25390625
# step = 100, loss = 8389.658203125
# step = 200, loss = 8000.15283203125
# step = 300, loss = 7735.2216796875
# step = 400, loss = 7528.6201171875
# step = 500, loss = 7349.75732421875
# step = 600, loss = 7168.712890625
# step = 700, loss = 7000.8740234375
# step = 800, loss = 6862.1396484375
# step = 900, loss = 6741.3125
# step = 1000, loss = 6623.7822265625
# step = 1100, loss = 6474.0693359375
# step = 1200, loss = 6352.73974609375
# step = 1300, loss = 6207.3369140625
# step = 1400, loss = 5989.3984375
# step = 1500, loss = 5531.5263671875
# step = 1600, loss = 5315.83203125
# step = 1700, loss = 5072.98583984375
# step = 1800, loss = 4571.0205078125
# step = 1900, loss = 4115.76953125
# step = 2000, loss = 3160.2275390625
# step = 2100, loss = 2192.803466796875
# step = 2200, loss = 2141.651123046875
# step = 2300, loss = 2099.07958984375
# step = 2400, loss = 2039.53955078125
# step = 2500, loss = 1975.3131103515625
# step = 2600, loss = 1893.64208984375
# step = 2700, loss = 1738.7447509765625
# step = 2800, loss = 1434.4779052734375
# step = 2900, loss = 1395.1845703125
# step = 3000, loss = 1326.5572509765625
# step = 3100, loss = 1249.547607421875
# step = 3200, loss = 1116.273193359375
# step = 3300, loss = 895.9677734375
# step = 3400, loss = 873.300537109375
# step = 3500, loss = 854.16943359375
# step = 3600, loss = 840.7384033203125
# step = 3700, loss = 825.3944091796875
# step = 3800, loss = 808.0265502929688
# step = 3900, loss = 794.2548828125
# step = 4000, loss = 779.6495361328125
# step = 4100, loss = 762.2307739257812
# step = 4200, loss = 744.0616455078125
# step = 4300, loss = 718.99560546875
# step = 4400, loss = 684.0884399414062
# step = 4500, loss = 626.7691650390625
# step = 4600, loss = 476.591552734375
# step = 4700, loss = 431.55767822265625
# step = 4800, loss = 423.995849609375
# step = 4900, loss = 418.558837890625
# step = 5000, loss = 413.9452209472656
# step = 5100, loss = 408.90203857421875
# step = 5200, loss = 408.6312561035156
# step = 5300, loss = 408.36285400390625
# step = 5400, loss = 408.09674072265625
# step = 5500, loss = 407.83282470703125
# step = 5600, loss = 407.571044921875
# step = 5700, loss = 407.31146240234375
# step = 5800, loss = 407.0542297363281
# step = 5900, loss = 406.7990417480469
# step = 6000, loss = 406.54583740234375
# step = 6100, loss = 406.29443359375
# step = 6200, loss = 406.04473876953125
# step = 6300, loss = 405.79644775390625
# step = 6400, loss = 405.5495910644531
# step = 6500, loss = 405.303955078125
# step = 6600, loss = 405.0594482421875
# step = 6700, loss = 404.8162536621094
# step = 6800, loss = 404.5742492675781
# step = 6900, loss = 404.3335266113281
# step = 7000, loss = 404.0941467285156
# step = 7100, loss = 403.85626220703125
# step = 7200, loss = 403.619873046875
# step = 7300, loss = 403.3851013183594
# step = 7400, loss = 403.15179443359375
# step = 7500, loss = 402.91998291015625
# step = 7600, loss = 402.6895751953125
# step = 7700, loss = 402.46038818359375
# step = 7800, loss = 402.23223876953125
# step = 7900, loss = 402.0048828125
# step = 8000, loss = 401.77813720703125
# step = 8100, loss = 401.5517272949219
# step = 8200, loss = 401.325439453125
# step = 8300, loss = 401.0992736816406
# step = 8400, loss = 400.8727722167969
# step = 8500, loss = 400.64593505859375
# step = 8600, loss = 400.4184875488281
# step = 8700, loss = 400.19036865234375
# step = 8800, loss = 399.9615783691406
# step = 8900, loss = 399.73199462890625
# step = 9000, loss = 399.501708984375
# step = 9100, loss = 399.27081298828125
# step = 9200, loss = 399.03948974609375
# step = 9300, loss = 398.8079833984375
# step = 9400, loss = 398.5765075683594
# step = 9500, loss = 398.3454284667969
# step = 9600, loss = 398.1148681640625
# step = 9700, loss = 397.88507080078125
# step = 9800, loss = 397.6561279296875
# step = 9900, loss = 397.4279479980469
# train_accuracy=0.8169999718666077
# test_accuracy=0.5569999814033508

# %%
plt.plot(lossi)

# %% [markdown]
# ### Step 2: Reference implementation using pytorch's .backward()
# Nothing to do in Step 2, this code is provided for you as a reference

# %%
w1, b1, w2, b2 = init()
parameters = [w1, b1, w2, b2]
for p in parameters:
    p.requires_grad_(True)

# %%
# reference code
torch.set_printoptions(linewidth=200)
import torch.nn as F

def train(w1, b1, w2, b2):
    lossi = []
    for step in range(10000):
        xb = train_input
        yb = train_target
        num_samples = xb.shape[0]
        # forward
        z1, h1, z2, h2 = forward(w1, b1, w2, b2, xb)
        xloss = F.MSELoss()
        lsi = xloss(h2, yb) * yb.nelement()
        # backward
        for p in parameters:
            p.grad = None
        lsi.backward()
        # update
        lr = 0.1 / num_samples
        for p in parameters:
            p.data += -lr * p.grad
        if step % 100 == 0: print(f'step = {step}, loss = {lsi}')
        lossi.append(lsi.item())
    # compute accuracy
    _, _, _, preds = forward(w1, b1, w2, b2, train_input)
    train_accuracy = compute_accuracy(preds, train_target)
    _, _, _, preds = forward(w1, b1, w2, b2, test_input)
    test_accuracy = compute_accuracy(preds, test_target)
    print(f'{train_accuracy=}')
    print(f'{test_accuracy=}')
    return lossi

# %%
lossi = train(w1, b1, w2, b2)
# Out:
# step = 0, loss = 9739.25390625
# step = 100, loss = 8393.513671875
# step = 200, loss = 7991.28955078125
# step = 300, loss = 7716.9013671875
# step = 400, loss = 7531.544921875
# step = 500, loss = 7359.16455078125
# step = 600, loss = 7200.154296875
# step = 700, loss = 7037.76904296875
# step = 800, loss = 6889.2626953125
# step = 900, loss = 6764.126953125
# step = 1000, loss = 6634.19140625
# step = 1100, loss = 6500.93505859375
# step = 1200, loss = 6366.80029296875
# step = 1300, loss = 6206.07177734375
# step = 1400, loss = 5964.15478515625
# step = 1500, loss = 5521.95068359375
# step = 1600, loss = 5329.8408203125
# step = 1700, loss = 5097.607421875
# step = 1800, loss = 4691.1953125
# step = 1900, loss = 4044.567138671875
# step = 2000, loss = 3217.34033203125
# step = 2100, loss = 2205.328369140625
# step = 2200, loss = 2128.921630859375
# step = 2300, loss = 2087.299072265625
# step = 2400, loss = 2037.724609375
# step = 2500, loss = 1982.3743896484375
# step = 2600, loss = 1917.000244140625
# step = 2700, loss = 1797.439697265625
# step = 2800, loss = 1448.371826171875
# step = 2900, loss = 1404.957275390625
# step = 3000, loss = 1326.2198486328125
# step = 3100, loss = 1246.2686767578125
# step = 3200, loss = 1055.6630859375
# step = 3300, loss = 905.166015625
# step = 3400, loss = 895.3408203125
# step = 3500, loss = 875.2307739257812
# step = 3600, loss = 851.2071533203125
# step = 3700, loss = 833.162841796875
# step = 3800, loss = 819.9067993164062
# step = 3900, loss = 806.0056762695312
# step = 4000, loss = 791.5281982421875
# step = 4100, loss = 783.1878662109375
# step = 4200, loss = 775.4345092773438
# step = 4300, loss = 765.725830078125
# step = 4400, loss = 754.680419921875
# step = 4500, loss = 739.4520874023438
# step = 4600, loss = 718.4553833007812
# step = 4700, loss = 688.9229736328125
# step = 4800, loss = 623.9448852539062
# step = 4900, loss = 451.21685791015625
# step = 5000, loss = 421.90228271484375
# step = 5100, loss = 412.55224609375
# step = 5200, loss = 406.83001708984375
# step = 5300, loss = 403.3139953613281
# step = 5400, loss = 400.6794738769531
# step = 5500, loss = 398.3759460449219
# step = 5600, loss = 396.20660400390625
# step = 5700, loss = 394.0665283203125
# step = 5800, loss = 391.87066650390625
# step = 5900, loss = 389.8428039550781
# step = 6000, loss = 387.82861328125
# step = 6100, loss = 385.8555603027344
# step = 6200, loss = 384.0223083496094
# step = 6300, loss = 382.2824401855469
# step = 6400, loss = 380.7345275878906
# step = 6500, loss = 379.2940673828125
# step = 6600, loss = 377.89910888671875
# step = 6700, loss = 376.47686767578125
# step = 6800, loss = 375.00665283203125
# step = 6900, loss = 373.6048583984375
# step = 7000, loss = 372.3083190917969
# step = 7100, loss = 371.0487060546875
# step = 7200, loss = 369.781494140625
# step = 7300, loss = 368.51007080078125
# step = 7400, loss = 367.4481201171875
# step = 7500, loss = 366.47802734375
# step = 7600, loss = 365.5843505859375
# step = 7700, loss = 364.73681640625
# step = 7800, loss = 363.89495849609375
# step = 7900, loss = 363.03900146484375
# step = 8000, loss = 362.2115173339844
# step = 8100, loss = 361.40374755859375
# step = 8200, loss = 360.6375427246094
# step = 8300, loss = 359.8851318359375
# step = 8400, loss = 359.1319885253906
# step = 8500, loss = 358.39593505859375
# step = 8600, loss = 357.6578674316406
# step = 8700, loss = 356.88958740234375
# step = 8800, loss = 356.05023193359375
# step = 8900, loss = 355.1634521484375
# step = 9000, loss = 354.2767333984375
# step = 9100, loss = 353.5001220703125
# step = 9200, loss = 352.7877197265625
# step = 9300, loss = 352.0948791503906
# step = 9400, loss = 351.41204833984375
# step = 9500, loss = 350.6210021972656
# step = 9600, loss = 349.9071044921875
# step = 9700, loss = 349.1994323730469
# step = 9800, loss = 348.479736328125
# step = 9900, loss = 347.7583312988281
# train_accuracy=0.8679999709129333
# test_accuracy=0.6019999980926514

# %%
plt.plot(lossi)

# %% [markdown]
# ### Step 3: Build the same MLP layer but with fully pytorch code (nn.Linear(), etc.)

# %%
# network dimensions
n_in = 784
n_hidden = 200
n_out = 10

# %%
X_tr, Y_tr = train_input, train_target
X_test, Y_test = test_input, test_target

# %%
class MLP(nn.Module):

    def __init__(self):
        super().__init__()
        self.layers = nn.ModuleList((
            nn.Linear(n_in, n_hidden),
            nn.Tanh(),
            nn.Linear(n_hidden, n_out),
            nn.Tanh()
        ))

    def __call__(self, x):
        for layer in self.layers:
            x = layer(x)
        return x
    
    def __parameters__(self):
        return [p for layer in self.layers for p in layer.parameters]

model = MLP()
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3)
loss_fn = nn.MSELoss()

# %%
# training
num_epochs = 10000

for n in range(num_epochs):
    y_pred = model(X_tr)
    loss = loss_fn(y_pred, Y_tr)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    if n % 1000 == 0: 
        with torch.no_grad():
            # train accuracy
            acc_train = compute_accuracy(y_pred, Y_tr)
            # test accuracy
            y_test_preds = model(X_test)
            acc_test = compute_accuracy(y_test_preds, Y_test)
            print(f'step = {n:6d}\tloss={loss.item():.5f}\taccuracy (train, test): {acc_train:.5f}\t{acc_test:.5f}')
# Out:
# step =      0	loss=0.17348	accuracy (train, test): 0.08500	0.20200
# step =   1000	loss=0.00076	accuracy (train, test): 1.00000	0.86900
# step =   2000	loss=0.00020	accuracy (train, test): 1.00000	0.87600
# step =   3000	loss=0.00010	accuracy (train, test): 1.00000	0.87700
# step =   4000	loss=0.00006	accuracy (train, test): 1.00000	0.87500
# step =   5000	loss=0.00008	accuracy (train, test): 1.00000	0.87400
# step =   6000	loss=0.00003	accuracy (train, test): 1.00000	0.87400
# step =   7000	loss=0.00009	accuracy (train, test): 1.00000	0.87500
# step =   8000	loss=0.00000	accuracy (train, test): 1.00000	0.87500
# step =   9000	loss=0.00008	accuracy (train, test): 1.00000	0.87400

# %% [markdown]
# ##### Exercise: try to improve accuracy!

# %% [markdown]
# A solution could be to increase the depth of the network, but the accuracy of 1 on the training set  after 1000 epochs tells us that the model probably overfits. To improve the model, we can use DropOut or regularization techniques

# %%
# network dimensions
n_in = 784
n_hidden = 500
n_out = 10

# %%
X_tr, Y_tr = train_input, train_target
X_test, Y_test = test_input, test_target

# %%
class MLP(nn.Module):

    def __init__(self):
        super().__init__()
        self.layers = nn.ModuleList((
            nn.Linear(n_in, n_hidden),
            nn.Tanh(),
            nn.Linear(n_hidden, n_out),
            nn.Tanh()
        ))

    def __call__(self, x):
        for layer in self.layers:
            x = layer(x)
        return x
    
    def __parameters__(self):
        return [p for layer in self.layers for p in layer.parameters]

model = MLP()
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3)
loss_fn = nn.MSELoss()

# %%
# training
num_epochs = 10000

for n in range(num_epochs):
    y_pred = model(X_tr)
    loss = loss_fn(y_pred, Y_tr)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    if n % 1000 == 0: 
        with torch.no_grad():
            # train accuracy
            acc_train = compute_accuracy(y_pred, Y_tr)
            # test accuracy
            y_test_preds = model(X_test)
            acc_test = compute_accuracy(y_test_preds, Y_test)
            print(f'step = {n:6d}\tloss={loss.item():.5f}\taccuracy (train, test): {acc_train:.5f}\t{acc_test:.5f}')
